# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

# %%
history
# Out:
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import scienceplots
# SecEm=pd.read_excel('Analysis2.xlsx', sheet_name="SecEm")
# Sector=SecEm['Sector']
# Em1990=SecEm["em1990"]
# Em2005=SecEm["em2005"]
# Em2010=SecEm["em2010"]
# Em2015=SecEm["em2015"]
# Em2020=SecEm["em2020"]
# Em2025=SecEm["em2025"]
# Em2030=SecEm["em2030"]
# Em2035=SecEm["em2035"]
# Em2040=SecEm["em2040"]
# Em2045=SecEm["em2045"]
# Em2050=SecEm["em2050"]
# E1990=sum(Em1990)*44/12
# E2005=sum(Em2005)*44/12
# E2010=sum(Em2010)*44/12
# E2015=sum(Em2015)*44/12
# E2020=sum(Em2020)*44/12
# E2025=sum(Em2025)*44/12
# E2030=sum(Em2030)*44/12
# E2035=sum(Em2035)*44/12
# E2040=sum(Em2040)*44/12
# E2045=sum(Em2045)*44/12
# E2050=sum(Em2050)*44/12
#
# print(
#     "2005 emission", E2005, "MtCO2",
#     "2050 emission", E2050, "MtCO2",
#     "Difference",(E2005-E2050)/E2005
# )
# SecEmB=pd.read_excel('Analysis2.xlsx', sheet_name="SecEmB")#B=Baseline
# SectorB=SecEmB['Sector']
# ...

# %%
SecEm=pd.read_excel('Analysis2.xlsx', sheet_name="SecEm")
